# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

# %%
hk_speed = pd.read_csv(r'C:\FILES\thesis-vsc-files\data\hk\hk_speed.csv')
hk_output_speed = pd.read_csv(r"C:\FILES\thesis-vsc-files\data\hk\roadnet_prediction.csv",header=None)
# Out:
# 0       35.125000
# 1       36.857143
# 2       36.375000
# 3       33.285714
# 4       32.750000
#           ...
# 1991    27.666667
# 1992    36.000000
# 1993    32.666667
# 1994    35.428571
# 1995    36.000000
# Name: 3369-33691, Length: 1996, dtype: float64

# %%
# BEFORE GCN
# roadnet1 stats
road1_stat = hk_speed[['3006-30069','30069-888301','3470-3006','888301-3692','3692-46332']].describe()

# # roadnet2 stats
road2_stat = hk_speed[['3393-88817','3395-3393','3681-3395','3417-3681','3419-3417']].describe()

# roadnet3 stats
road3_stat = hk_speed[['3363-3369','33671-3363','33691-33671','3369-33691']].describe()

# AFTER GCN
road1_statgcn = hk_output_speed[[3,4,9,7]].iloc[1:]
road1_statgcn = (70*road1_statgcn).describe()
road1_statgcn = road1_statgcn.iloc[1:]
display(road1_statgcn)
# Out:
#               3          4          9          7
# mean  25.314446  23.986295  23.563694  23.104565
# std    7.082241   7.417647   8.910522   8.311560
# min   14.813025  13.166894  10.652390  11.258406
# 25%   18.448450  17.216670  15.361048  15.102388
# 50%   23.071958  21.209028  20.573904  21.059927
# 75%   33.157030  32.164405  33.732416  33.039676
# max   36.454803  37.013774  38.443466  35.796255

# %%
# roadnet1 data visualization

sns.set(style='whitegrid')
plt.figure(figsize=(10,10))
plt.subplot(3,2,1)
sns.violinplot(y='3006-30069',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 0')
plt.subplot(3,2,2)
sns.violinplot(y='30069-888301',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 1')
plt.subplot(3,2,3)
sns.violinplot(y='3470-3006',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 39')
plt.subplot(3,2,4)
sns.violinplot(y='888301-3692',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 167')
plt.subplot(3,2,5)
sns.violinplot(y='3692-46332',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 76')
# plt.legend(labels=['Node 0', 'Node 1', 'Node 39', 'Node 167', 'Node 76'])
plt.show()

# %%
# roadnet2 data visualization

sns.set(style='whitegrid')
plt.figure(figsize=(10,10))
plt.subplot(3,2,1)
sns.violinplot(y='3393-88817',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 12')
plt.subplot(3,2,2)
sns.violinplot(y='3395-3393',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 13')
plt.subplot(3,2,3)
sns.violinplot(y='3681-3395',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 72')
plt.subplot(3,2,4)
sns.violinplot(y='3417-3681',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 15')
plt.subplot(3, 2, 5)
sns.violinplot(y='3419-3417',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 16')
plt.show()

# %%
# roadnet3 data visualization

sns.set(style='whitegrid')
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.violinplot(y='3363-3369',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 3')
plt.subplot(2,2,2)
sns.violinplot(y='33671-3363',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 4')
plt.subplot(2,2,3)
sns.violinplot(y='33691-33671',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 9')
plt.subplot(2,2,4)
sns.violinplot(y='3369-33691',data=hk_speed, fill=None)
plt.ylabel('Speed')
plt.xlabel('Node 7')
plt.show()
